# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.

# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Import the random module
import random

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
#Create a list for holding the cities
cities = []
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 777

# %%
#Import the requests library
import requests

#Import the API key
from config import weather_api_key

# %%
#Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data = []
#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in the list
for i, city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count += 1

#Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        #Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

#If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | hargeysa
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | vila velha
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | mayo
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | bac lieu
# Processing Record 19 of Set 1 | bonavista
# Processing Record 20 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | san lorenzo
# Processing Record 25 of Set 1 | shimoda
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | janow lubelski
# Processing Record 30 of Set 1 | bakchar
# Processing Record 31 of Set 1 | havre-saint-pierre
# Processing Record 32 of Set 1 | wukari
# Processing Record 33 of Set 1 | nakusp
# Processing Record 34 of Set 1 | sept-iles
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | gasa
# Processing Record 37 of Set 1 | xichang
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | dingle
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | nouadhibou
# Processing Record 47 of Set 1 | takanosu
# Processing Record 48 of Set 1 | nuuk
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | karratha
# Processing Record 1 of Set 2 | ilhabela
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | grindavik
# Processing Record 4 of Set 2 | constitucion
# Processing Record 5 of Set 2 | gorontalo
# Processing Record 6 of Set 2 | khormuj
# City not found. Skipping...
# Processing Record 7 of Set 2 | sorland
# Processing Record 8 of Set 2 | chornobay
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | plettenberg bay
# Processing Record 11 of Set 2 | oistins
# Processing Record 12 of Set 2 | reconquista
# City not found. Skipping...
# Processing Record 13 of Set 2 | saint-georges
# Processing Record 14 of Set 2 | port hardy
# Processing Record 15 of Set 2 | maceio
# Processing Record 16 of Set 2 | san cristobal
# Processing Record 17 of Set 2 | coahuayana
# Processing Record 18 of Set 2 | san quintin
# Processing Record 19 of Set 2 | andra
# Processing Record 20 of Set 2 | bilibino
# Processing Record 21 of Set 2 | wageningen
# Processing Record 22 of Set 2 | poreba
# Processing Record 23 of Set 2 | ostrovnoy
# Processing Record 24 of Set 2 | paris
# Processing Record 25 of Set 2 | inhambane
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | kahului
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | zavodouspenskoye
# Processing Record 30 of Set 2 | dabra
# Processing Record 31 of Set 2 | boddam
# Processing Record 32 of Set 2 | cartagena
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | warrington
# Processing Record 36 of Set 2 | villefranche-de-rouergue
# Processing Record 37 of Set 2 | kirakira
# Processing Record 38 of Set 2 | cuamba
# Processing Record 39 of Set 2 | kargil
# Processing Record 40 of Set 2 | luderitz
# Processing Record 41 of Set 2 | mahebourg
# Processing Record 42 of Set 2 | kamenka
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | isangel
# Processing Record 45 of Set 2 | tarabuco
# Processing Record 46 of Set 2 | fort-de-france
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 3 | hamilton
# Processing Record 2 of Set 3 | bayji
# Processing Record 3 of Set 3 | port-gentil
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | mataura
# Processing Record 6 of Set 3 | talah
# City not found. Skipping...
# Processing Record 7 of Set 3 | ocos
# Processing Record 8 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 9 of Set 3 | esna
# Processing Record 10 of Set 3 | cherskiy
# Processing Record 11 of Set 3 | lamu
# Processing Record 12 of Set 3 | ilulissat
# Processing Record 13 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | aleksandrov gay
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | ambilobe
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | basco
# Processing Record 21 of Set 3 | bani
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | inirida
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | empa
# City not found. Skipping...
# Processing Record 29 of Set 3 | key largo
# Processing Record 30 of Set 3 | thompson
# Processing Record 31 of Set 3 | ondjiva
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | port hedland
# Processing Record 34 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 3 | katima mulilo
# Processing Record 36 of Set 3 | sainthia
# Processing Record 37 of Set 3 | kralendijk
# Processing Record 38 of Set 3 | lompoc
# Processing Record 39 of Set 3 | marquette
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | kurumkan
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | black river
# Processing Record 45 of Set 3 | marsa matruh
# Processing Record 46 of Set 3 | bantry
# Processing Record 47 of Set 3 | killybegs
# Processing Record 48 of Set 3 | touros
# Processing Record 49 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 3 | shitanjing
# Processing Record 1 of Set 4 | zhigansk
# Processing Record 2 of Set 4 | pudozh
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 4 | walvis bay
# Processing Record 5 of Set 4 | faya
# Processing Record 6 of Set 4 | saint george
# Processing Record 7 of Set 4 | sinjar
# Processing Record 8 of Set 4 | necochea
# Processing Record 9 of Set 4 | broken hill
# Processing Record 10 of Set 4 | maumere
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | ejura
# Processing Record 14 of Set 4 | ingham
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | ust-shonosha
# Processing Record 17 of Set 4 | nandyal
# Processing Record 18 of Set 4 | turukhansk
# Processing Record 19 of Set 4 | longyearbyen
# Processing Record 20 of Set 4 | sibu
# Processing Record 21 of Set 4 | fiumicino
# Processing Record 22 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | strezhevoy
# Processing Record 25 of Set 4 | simplicio mendes
# Processing Record 26 of Set 4 | meulaboh
# Processing Record 27 of Set 4 | bogovarovo
# Processing Record 28 of Set 4 | san matias
# Processing Record 29 of Set 4 | ucluelet
# Processing Record 30 of Set 4 | sinnamary
# Processing Record 31 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | hambantota
# Processing Record 34 of Set 4 | peniche
# Processing Record 35 of Set 4 | gallup
# Processing Record 36 of Set 4 | bom jesus do itabapoana
# Processing Record 37 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 4 | pacific grove
# Processing Record 39 of Set 4 | sao filipe
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | penzance
# Processing Record 43 of Set 4 | mingshui
# Processing Record 44 of Set 4 | batagay-alyta
# Processing Record 45 of Set 4 | jumla
# Processing Record 46 of Set 4 | butaritari
# Processing Record 47 of Set 4 | aksay
# Processing Record 48 of Set 4 | kholodnyy
# Processing Record 49 of Set 4 | georgetown
# Processing Record 50 of Set 4 | homer
# Processing Record 1 of Set 5 | mar del plata
# Processing Record 2 of Set 5 | erzin
# Processing Record 3 of Set 5 | east london
# Processing Record 4 of Set 5 | cairns
# Processing Record 5 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 5 | urumqi
# Processing Record 7 of Set 5 | port elizabeth
# Processing Record 8 of Set 5 | buon me thuot
# City not found. Skipping...
# Processing Record 9 of Set 5 | sudak
# Processing Record 10 of Set 5 | kongolo
# Processing Record 11 of Set 5 | mount isa
# Processing Record 12 of Set 5 | severo-kurilsk
# Processing Record 13 of Set 5 | chokurdakh
# Processing Record 14 of Set 5 | lagos
# Processing Record 15 of Set 5 | ponta delgada
# Processing Record 16 of Set 5 | saravan
# Processing Record 17 of Set 5 | saldanha
# Processing Record 18 of Set 5 | sao jose da coroa grande
# Processing Record 19 of Set 5 | estelle
# Processing Record 20 of Set 5 | boquira
# Processing Record 21 of Set 5 | mareeba
# Processing Record 22 of Set 5 | takoradi
# Processing Record 23 of Set 5 | kathu
# Processing Record 24 of Set 5 | harbin
# Processing Record 25 of Set 5 | yinchuan
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | chuy
# Processing Record 28 of Set 5 | gizo
# Processing Record 29 of Set 5 | tiksi
# Processing Record 30 of Set 5 | beringovskiy
# Processing Record 31 of Set 5 | sao joao da barra
# Processing Record 32 of Set 5 | whitehorse
# Processing Record 33 of Set 5 | phan thiet
# Processing Record 34 of Set 5 | port blair
# Processing Record 35 of Set 5 | cabo san lucas
# Processing Record 36 of Set 5 | avarua
# Processing Record 37 of Set 5 | lahij
# Processing Record 38 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 5 | saint-augustin
# Processing Record 40 of Set 5 | udachnyy
# Processing Record 41 of Set 5 | benguela
# Processing Record 42 of Set 5 | smolenka
# Processing Record 43 of Set 5 | namatanai
# Processing Record 44 of Set 5 | kodiak
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | pangnirtung
# Processing Record 47 of Set 5 | henties bay
# Processing Record 48 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 5 | boende
# Processing Record 50 of Set 5 | baiyin
# Processing Record 1 of Set 6 | alugan
# Processing Record 2 of Set 6 | yulara
# Processing Record 3 of Set 6 | beruni
# City not found. Skipping...
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | ponta do sol
# Processing Record 6 of Set 6 | toftir
# City not found. Skipping...
# Processing Record 7 of Set 6 | chumikan
# Processing Record 8 of Set 6 | biloxi
# Processing Record 9 of Set 6 | yatou
# Processing Record 10 of Set 6 | nanakuli
# Processing Record 11 of Set 6 | cedar city
# Processing Record 12 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 6 | vardo
# Processing Record 14 of Set 6 | feijo
# Processing Record 15 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 16 of Set 6 | westport
# Processing Record 17 of Set 6 | bonthe
# Processing Record 18 of Set 6 | geraldton
# Processing Record 19 of Set 6 | tomatlan
# Processing Record 20 of Set 6 | zaykovo
# Processing Record 21 of Set 6 | inzer
# Processing Record 22 of Set 6 | aragarcas
# Processing Record 23 of Set 6 | mahina
# Processing Record 24 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 6 | arucas
# Processing Record 26 of Set 6 | kangaatsiaq
# Processing Record 27 of Set 6 | srednekolymsk
# Processing Record 28 of Set 6 | lebu
# Processing Record 29 of Set 6 | matagami
# Processing Record 30 of Set 6 | airai
# Processing Record 31 of Set 6 | san angelo
# Processing Record 32 of Set 6 | belmonte
# Processing Record 33 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 6 | terrenate
# Processing Record 35 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 6 | morgan city
# Processing Record 37 of Set 6 | sorong
# Processing Record 38 of Set 6 | beloha
# Processing Record 39 of Set 6 | kendallville
# Processing Record 40 of Set 6 | martil
# Processing Record 41 of Set 6 | gafanha da encarnacao
# Processing Record 42 of Set 6 | caninde de sao francisco
# Processing Record 43 of Set 6 | artyom
# Processing Record 44 of Set 6 | acapulco
# Processing Record 45 of Set 6 | ribeira grande
# Processing Record 46 of Set 6 | moose factory
# Processing Record 47 of Set 6 | yuksekova
# Processing Record 48 of Set 6 | progreso
# Processing Record 49 of Set 6 | yar-sale
# Processing Record 50 of Set 6 | chilca
# Processing Record 1 of Set 7 | gurupi
# Processing Record 2 of Set 7 | nassau
# Processing Record 3 of Set 7 | pevek
# Processing Record 4 of Set 7 | itoman
# Processing Record 5 of Set 7 | aktash
# Processing Record 6 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 7 of Set 7 | suoyarvi
# Processing Record 8 of Set 7 | dwarka
# Processing Record 9 of Set 7 | yeppoon
# Processing Record 10 of Set 7 | oranjemund
# Processing Record 11 of Set 7 | broome
# Processing Record 12 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 13 of Set 7 | bedi
# Processing Record 14 of Set 7 | tilichiki
# Processing Record 15 of Set 7 | babu
# Processing Record 16 of Set 7 | bitkine
# Processing Record 17 of Set 7 | meghraj
# Processing Record 18 of Set 7 | san marcos
# Processing Record 19 of Set 7 | quatre cocos
# Processing Record 20 of Set 7 | paamiut
# Processing Record 21 of Set 7 | nikel
# Processing Record 22 of Set 7 | tambura
# Processing Record 23 of Set 7 | maningrida
# Processing Record 24 of Set 7 | murray bridge
# Processing Record 25 of Set 7 | tubarao
# Processing Record 26 of Set 7 | khudumelapye
# Processing Record 27 of Set 7 | marawi
# Processing Record 28 of Set 7 | rabak
# Processing Record 29 of Set 7 | fukagawa
# Processing Record 30 of Set 7 | qostanay
# Processing Record 31 of Set 7 | maldonado
# Processing Record 32 of Set 7 | guarapari
# Processing Record 33 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 34 of Set 7 | pontianak
# Processing Record 35 of Set 7 | yenagoa
# Processing Record 36 of Set 7 | port macquarie
# Processing Record 37 of Set 7 | kruisfontein
# Processing Record 38 of Set 7 | polewali
# Processing Record 39 of Set 7 | pemba
# Processing Record 40 of Set 7 | imbituba
# Processing Record 41 of Set 7 | kualakapuas
# Processing Record 42 of Set 7 | chapais
# Processing Record 43 of Set 7 | maymyo
# Processing Record 44 of Set 7 | kananga
# Processing Record 45 of Set 7 | uelzen
# Processing Record 46 of Set 7 | ravar
# Processing Record 47 of Set 7 | ormara
# Processing Record 48 of Set 7 | gabu
# Processing Record 49 of Set 7 | belaya gora
# Processing Record 50 of Set 7 | bengkulu
# Processing Record 1 of Set 8 | ahipara
# Processing Record 2 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 8 | tokur
# Processing Record 4 of Set 8 | sangar
# Processing Record 5 of Set 8 | chelmza
# Processing Record 6 of Set 8 | iskateley
# Processing Record 7 of Set 8 | cananea
# Processing Record 8 of Set 8 | los llanos de aridane
# Processing Record 9 of Set 8 | abadiania
# Processing Record 10 of Set 8 | fairbanks
# Processing Record 11 of Set 8 | quesnel
# Processing Record 12 of Set 8 | maiduguri
# Processing Record 13 of Set 8 | deputatskiy
# Processing Record 14 of Set 8 | awbari
# Processing Record 15 of Set 8 | guerrero negro
# Processing Record 16 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 8 | flin flon
# Processing Record 18 of Set 8 | erenhot
# Processing Record 19 of Set 8 | alipur
# Processing Record 20 of Set 8 | hede
# Processing Record 21 of Set 8 | creel
# Processing Record 22 of Set 8 | nenjiang
# Processing Record 23 of Set 8 | noyabrsk
# Processing Record 24 of Set 8 | vogan
# Processing Record 25 of Set 8 | lakselv
# Processing Record 26 of Set 8 | rudnaya pristan
# Processing Record 27 of Set 8 | hovd
# Processing Record 28 of Set 8 | port lincoln
# Processing Record 29 of Set 8 | maniitsoq
# Processing Record 30 of Set 8 | neuquen
# Processing Record 31 of Set 8 | korce
# Processing Record 32 of Set 8 | aklavik
# Processing Record 33 of Set 8 | athabasca
# Processing Record 34 of Set 8 | itaquitinga
# Processing Record 35 of Set 8 | kendari
# Processing Record 36 of Set 8 | hasaki
# Processing Record 37 of Set 8 | thrissur
# Processing Record 38 of Set 8 | bodden town
# Processing Record 39 of Set 8 | porto torres
# Processing Record 40 of Set 8 | san rafael
# Processing Record 41 of Set 8 | colares
# Processing Record 42 of Set 8 | kulhudhuffushi
# Processing Record 43 of Set 8 | dicabisagan
# Processing Record 44 of Set 8 | harper
# Processing Record 45 of Set 8 | rio grande
# Processing Record 46 of Set 8 | cape coast
# Processing Record 47 of Set 8 | iranshahr
# Processing Record 48 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 8 | sao felix do xingu
# Processing Record 50 of Set 8 | aden
# Processing Record 1 of Set 9 | causwagan
# Processing Record 2 of Set 9 | senj
# Processing Record 3 of Set 9 | rocky mountain house
# Processing Record 4 of Set 9 | talcahuano
# Processing Record 5 of Set 9 | searcy
# Processing Record 6 of Set 9 | thessalon
# Processing Record 7 of Set 9 | avera
# Processing Record 8 of Set 9 | pisco
# Processing Record 9 of Set 9 | andenes
# Processing Record 10 of Set 9 | ust-uda
# Processing Record 11 of Set 9 | san jose de rio tinto
# Processing Record 12 of Set 9 | grand gaube
# Processing Record 13 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 9 | manadhoo
# Processing Record 15 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 9 | bousso
# Processing Record 17 of Set 9 | sobolevo
# Processing Record 18 of Set 9 | noshiro
# Processing Record 19 of Set 9 | umtata
# Processing Record 20 of Set 9 | kemin
# Processing Record 21 of Set 9 | tautira
# Processing Record 22 of Set 9 | asau
# Processing Record 23 of Set 9 | polyarnyy
# Processing Record 24 of Set 9 | sisimiut
# Processing Record 25 of Set 9 | adamclisi
# Processing Record 26 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 9 | outlook
# Processing Record 28 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 9 | hammond
# Processing Record 30 of Set 9 | monywa
# Processing Record 31 of Set 9 | riyadh
# Processing Record 32 of Set 9 | krasnoselkup
# Processing Record 33 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 9 | annau
# Processing Record 35 of Set 9 | hofn
# Processing Record 36 of Set 9 | berlevag
# Processing Record 37 of Set 9 | puerto colombia
# Processing Record 38 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 9 | chara
# Processing Record 40 of Set 9 | bandarbeyla
# Processing Record 41 of Set 9 | vestmannaeyjar
# Processing Record 42 of Set 9 | kupang
# Processing Record 43 of Set 9 | college
# Processing Record 44 of Set 9 | byron bay
# Processing Record 45 of Set 9 | dergaon
# Processing Record 46 of Set 9 | coihaique
# Processing Record 47 of Set 9 | blackwater
# Processing Record 48 of Set 9 | sungaipenuh
# Processing Record 49 of Set 9 | humaita
# Processing Record 50 of Set 9 | chifeng
# Processing Record 1 of Set 10 | pirojpur
# Processing Record 2 of Set 10 | marabba
# Processing Record 3 of Set 10 | leamington
# Processing Record 4 of Set 10 | preobrazheniye
# Processing Record 5 of Set 10 | semey
# Processing Record 6 of Set 10 | esso
# Processing Record 7 of Set 10 | pingzhuang
# Processing Record 8 of Set 10 | murdochville
# Processing Record 9 of Set 10 | ust-nera
# Processing Record 10 of Set 10 | casambalangan
# Processing Record 11 of Set 10 | cristalina
# Processing Record 12 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 10 | tuy hoa
# Processing Record 14 of Set 10 | waingapu
# Processing Record 15 of Set 10 | klaksvik
# Processing Record 16 of Set 10 | padang
# Processing Record 17 of Set 10 | tagusao
# Processing Record 18 of Set 10 | george town
# Processing Record 19 of Set 10 | gujar khan
# Processing Record 20 of Set 10 | baza
# Processing Record 21 of Set 10 | nantucket
# Processing Record 22 of Set 10 | nikolskoye
# Processing Record 23 of Set 10 | victoria
# Processing Record 24 of Set 10 | herat
# Processing Record 25 of Set 10 | talnakh
# Processing Record 26 of Set 10 | comodoro rivadavia
# Processing Record 27 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 10 | bocaiuva
# Processing Record 29 of Set 10 | hetauda
# Processing Record 30 of Set 10 | auki
# Processing Record 31 of Set 10 | masterton
# Processing Record 32 of Set 10 | hobe sound
# Processing Record 33 of Set 10 | tabou
# Processing Record 34 of Set 10 | wanning
# Processing Record 35 of Set 10 | hammerfest
# Processing Record 36 of Set 10 | ust-kulom
# Processing Record 37 of Set 10 | ono
# Processing Record 38 of Set 10 | nampula
# Processing Record 39 of Set 10 | tupik
# Processing Record 40 of Set 10 | sangin
# Processing Record 41 of Set 10 | le port
# Processing Record 42 of Set 10 | changji
# Processing Record 43 of Set 10 | odessa
# Processing Record 44 of Set 10 | buala
# Processing Record 45 of Set 10 | razole
# Processing Record 46 of Set 10 | paducah
# Processing Record 47 of Set 10 | chalmette
# Processing Record 48 of Set 10 | frejus
# Processing Record 49 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 1 of Set 11 | makakilo city
# Processing Record 2 of Set 11 | lorengau
# Processing Record 3 of Set 11 | vila franca do campo
# Processing Record 4 of Set 11 | balakhta
# Processing Record 5 of Set 11 | riohacha
# Processing Record 6 of Set 11 | morros
# Processing Record 7 of Set 11 | la primavera
# Processing Record 8 of Set 11 | causapscal
# Processing Record 9 of Set 11 | abu samrah
# Processing Record 10 of Set 11 | tungor
# Processing Record 11 of Set 11 | bridgewater
# Processing Record 12 of Set 11 | lima
# Processing Record 13 of Set 11 | qasigiannguit
# Processing Record 14 of Set 11 | milkovo
# Processing Record 15 of Set 11 | vostok
# Processing Record 16 of Set 11 | makaha
# Processing Record 17 of Set 11 | kieta
# Processing Record 18 of Set 11 | mangai
# Processing Record 19 of Set 11 | palmerston
# Processing Record 20 of Set 11 | malaya vishera
# Processing Record 21 of Set 11 | esperance
# Processing Record 22 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 11 | tab
# Processing Record 24 of Set 11 | dzaoudzi
# Processing Record 25 of Set 11 | haines junction
# Processing Record 26 of Set 11 | tera
# Processing Record 27 of Set 11 | shimonoseki
# Processing Record 28 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 29 of Set 11 | caravelas
# Processing Record 30 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 31 of Set 11 | flinders
# Processing Record 32 of Set 11 | kamaishi
# Processing Record 33 of Set 11 | tekirdag
# Processing Record 34 of Set 11 | salym
# Processing Record 35 of Set 11 | bastia
# Processing Record 36 of Set 11 | poum
# Processing Record 37 of Set 11 | kyren
# Processing Record 38 of Set 11 | reyes
# Processing Record 39 of Set 11 | poronaysk
# Processing Record 40 of Set 11 | kizhinga
# Processing Record 41 of Set 11 | florence
# Processing Record 42 of Set 11 | tessalit
# Processing Record 43 of Set 11 | sakakah
# Processing Record 44 of Set 11 | sabinas hidalgo
# Processing Record 45 of Set 11 | bulungu
# Processing Record 46 of Set 11 | pabrade
# Processing Record 47 of Set 11 | ossora
# Processing Record 48 of Set 11 | calbuco
# Processing Record 49 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 11 | myitkyina
# Processing Record 1 of Set 12 | kuytun
# Processing Record 2 of Set 12 | husavik
# Processing Record 3 of Set 12 | guiratinga
# Processing Record 4 of Set 12 | otane
# Processing Record 5 of Set 12 | bria
# Processing Record 6 of Set 12 | puerto escondido
# Processing Record 7 of Set 12 | rovaniemi
# Processing Record 8 of Set 12 | mogadishu
# Processing Record 9 of Set 12 | chernyshevskiy
# Processing Record 10 of Set 12 | nemuro
# Processing Record 11 of Set 12 | agapovka
# Processing Record 12 of Set 12 | sulangan
# Processing Record 13 of Set 12 | japura
# Processing Record 14 of Set 12 | mwene-ditu
# Processing Record 15 of Set 12 | khuzdar
# Processing Record 16 of Set 12 | saquena
# Processing Record 17 of Set 12 | honiara
# Processing Record 18 of Set 12 | tommot
# Processing Record 19 of Set 12 | torbay
# Processing Record 20 of Set 12 | goure
# Processing Record 21 of Set 12 | narsaq
# Processing Record 22 of Set 12 | mehamn
# Processing Record 23 of Set 12 | venado tuerto
# Processing Record 24 of Set 12 | nakhodka
# Processing Record 25 of Set 12 | jucurutu
# Processing Record 26 of Set 12 | niimi
# Processing Record 27 of Set 12 | manyana
# Processing Record 28 of Set 12 | tuatapere
# Processing Record 29 of Set 12 | zabaykalsk
# Processing Record 30 of Set 12 | khilok
# Processing Record 31 of Set 12 | dakar
# Processing Record 32 of Set 12 | liku
# Processing Record 33 of Set 12 | rayevskiy
# Processing Record 34 of Set 12 | santa cruz de tenerife
# Processing Record 35 of Set 12 | namwala
# Processing Record 36 of Set 12 | manubah
# City not found. Skipping...
# Processing Record 37 of Set 12 | calabar
# Processing Record 38 of Set 12 | waddan
# Processing Record 39 of Set 12 | namtsy
# Processing Record 40 of Set 12 | te anau
# Processing Record 41 of Set 12 | pinsk
# Processing Record 42 of Set 12 | imeni zhelyabova
# Processing Record 43 of Set 12 | sioux lookout
# Processing Record 44 of Set 12 | nerchinskiy zavod
# Processing Record 45 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 12 | komsomolskiy
# Processing Record 47 of Set 12 | juru
# Processing Record 48 of Set 12 | outjo
# Processing Record 49 of Set 12 | owando
# Processing Record 50 of Set 12 | urk
# Processing Record 1 of Set 13 | belozerskoye
# Processing Record 2 of Set 13 | ahuimanu
# Processing Record 3 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 4 of Set 13 | martyush
# Processing Record 5 of Set 13 | praia da vitoria
# Processing Record 6 of Set 13 | tabuk
# Processing Record 7 of Set 13 | rosarito
# Processing Record 8 of Set 13 | sur
# Processing Record 9 of Set 13 | angoche
# Processing Record 10 of Set 13 | brainerd
# Processing Record 11 of Set 13 | olkhovka
# Processing Record 12 of Set 13 | egvekinot
# Processing Record 13 of Set 13 | badiraguato
# Processing Record 14 of Set 13 | ous
# Processing Record 15 of Set 13 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 13 | verkhnyaya toyma
# Processing Record 17 of Set 13 | cayenne
# Processing Record 18 of Set 13 | zhangye
# Processing Record 19 of Set 13 | aitape
# Processing Record 20 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 21 of Set 13 | keetmanshoop
# Processing Record 22 of Set 13 | amapa
# Processing Record 23 of Set 13 | kushmurun
# Processing Record 24 of Set 13 | tsiroanomandidy
# Processing Record 25 of Set 13 | karymskoye
# Processing Record 26 of Set 13 | ulety
# Processing Record 27 of Set 13 | ankazoabo
# Processing Record 28 of Set 13 | tura
# Processing Record 29 of Set 13 | kamenz
# Processing Record 30 of Set 13 | nyurba
# Processing Record 31 of Set 13 | half moon bay
# Processing Record 32 of Set 13 | tabas
# Processing Record 33 of Set 13 | goya
# Processing Record 34 of Set 13 | venado
# Processing Record 35 of Set 13 | lady lake
# Processing Record 36 of Set 13 | launceston
# Processing Record 37 of Set 13 | kloulklubed
# Processing Record 38 of Set 13 | ugoofaaru
# Processing Record 39 of Set 13 | camacha
# Processing Record 40 of Set 13 | zambezi
# Processing Record 41 of Set 13 | vallenar
# Processing Record 42 of Set 13 | ozernovskiy
# Processing Record 43 of Set 13 | danielskuil
# Processing Record 44 of Set 13 | serendah
# Processing Record 45 of Set 13 | mahon
# Processing Record 46 of Set 13 | novosysoyevka
# Processing Record 47 of Set 13 | kimbe
# Processing Record 48 of Set 13 | san carlos de bariloche
# Processing Record 49 of Set 13 | fengzhen
# Processing Record 50 of Set 13 | sabha
# Processing Record 1 of Set 14 | jaranwala
# Processing Record 2 of Set 14 | quthing
# Processing Record 3 of Set 14 | lufilufi
# Processing Record 4 of Set 14 | xining
# Processing Record 5 of Set 14 | ambon
# Processing Record 6 of Set 14 | fortuna
# Processing Record 7 of Set 14 | teguise
# Processing Record 8 of Set 14 | alabat
# Processing Record 9 of Set 14 | luba
# Processing Record 10 of Set 14 | san juan tilapa
# Processing Record 11 of Set 14 | ystad
# Processing Record 12 of Set 14 | san pedro
# Processing Record 13 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 14 of Set 14 | wanlaweyn
# Processing Record 15 of Set 14 | havoysund
# Processing Record 16 of Set 14 | alofi
# Processing Record 17 of Set 14 | plyussa
# Processing Record 18 of Set 14 | sarankhola
# Processing Record 19 of Set 14 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 20 of Set 14 | rio gallegos
# Processing Record 21 of Set 14 | samana
# Processing Record 22 of Set 14 | kokopo
# Processing Record 23 of Set 14 | manta
# Processing Record 24 of Set 14 | high level
# Processing Record 25 of Set 14 | sarahan
# Processing Record 26 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 27 of Set 14 | kodinsk
# Processing Record 28 of Set 14 | porto belo
# Processing Record 29 of Set 14 | joao pinheiro
# Processing Record 30 of Set 14 | kaniama
# Processing Record 31 of Set 14 | lastoursville
# Processing Record 32 of Set 14 | tecoanapa
# Processing Record 33 of Set 14 | saint-paul
# Processing Record 34 of Set 14 | lages
# Processing Record 35 of Set 14 | solone
# Processing Record 36 of Set 14 | karistos
# City not found. Skipping...
# Processing Record 37 of Set 14 | laguna
# Processing Record 38 of Set 14 | zenzeli
# Processing Record 39 of Set 14 | moengo
# Processing Record 40 of Set 14 | viedma
# Processing Record 41 of Set 14 | uyuni
# Processing Record 42 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 14 | malatya
# Processing Record 44 of Set 14 | tawang
# Processing Record 45 of Set 14 | evensk
# Processing Record 46 of Set 14 | hamadan
# Processing Record 47 of Set 14 | shangqiu
# Processing Record 48 of Set 14 | arawa
# Processing Record 49 of Set 14 | oranjestad
# Processing Record 50 of Set 14 | santa maria
# Processing Record 1 of Set 15 | corner brook
# Processing Record 2 of Set 15 | centralia
# Processing Record 3 of Set 15 | tan an
# Processing Record 4 of Set 15 | lavrentiya
# Processing Record 5 of Set 15 | otavi
# Processing Record 6 of Set 15 | vestmanna
# Processing Record 7 of Set 15 | katangli
# Processing Record 8 of Set 15 | akyab
# Processing Record 9 of Set 15 | olymskiy
# City not found. Skipping...
# Processing Record 10 of Set 15 | kutum
# Processing Record 11 of Set 15 | barillas
# Processing Record 12 of Set 15 | srandakan
# Processing Record 13 of Set 15 | sven
# Processing Record 14 of Set 15 | san patricio
# Processing Record 15 of Set 15 | saint-jean-port-joli
# Processing Record 16 of Set 15 | tshikapa
# Processing Record 17 of Set 15 | osa
# Processing Record 18 of Set 15 | umm lajj
# Processing Record 19 of Set 15 | kaeo
# Processing Record 20 of Set 15 | urucara
# Processing Record 21 of Set 15 | el salto
# Processing Record 22 of Set 15 | saint-pierre
# Processing Record 23 of Set 15 | banjarmasin
# Processing Record 24 of Set 15 | arona
# Processing Record 25 of Set 15 | adrar
# Processing Record 26 of Set 15 | palu
# Processing Record 27 of Set 15 | grants
# Processing Record 28 of Set 15 | huitziltepec
# Processing Record 29 of Set 15 | alexandria
# Processing Record 30 of Set 15 | sinnar
# Processing Record 31 of Set 15 | bourail
# Processing Record 32 of Set 15 | san andres
# Processing Record 33 of Set 15 | nachalovo
# Processing Record 34 of Set 15 | venice
# Processing Record 35 of Set 15 | vanimo
# Processing Record 36 of Set 15 | barwaha
# City not found. Skipping...
# Processing Record 37 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 38 of Set 15 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 39 of Set 15 | zemio
# Processing Record 40 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 15 | toppenish
# Processing Record 42 of Set 15 | tazovskiy
# Processing Record 43 of Set 15 | sola
# Processing Record 44 of Set 15 | dongsheng
# Processing Record 45 of Set 15 | mandalgovi
# Processing Record 46 of Set 15 | marsaxlokk
# Processing Record 47 of Set 15 | okha
# Processing Record 48 of Set 15 | carmen
# Processing Record 49 of Set 15 | bubaque
# Processing Record 50 of Set 15 | guelengdeng
# City not found. Skipping...
# Processing Record 1 of Set 16 | matara
# Processing Record 2 of Set 16 | bucerias
# Processing Record 3 of Set 16 | terra santa
# Processing Record 4 of Set 16 | ksenyevka
# City not found. Skipping...
# Processing Record 5 of Set 16 | camocim
# Processing Record 6 of Set 16 | naze
# Processing Record 7 of Set 16 | qaqortoq
# Processing Record 8 of Set 16 | sokolka
# Processing Record 9 of Set 16 | carutapera
# Processing Record 10 of Set 16 | sile
# Processing Record 11 of Set 16 | bontang
# Processing Record 12 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 16 | bulgan
# Processing Record 14 of Set 16 | havelock
# Processing Record 15 of Set 16 | ilula
# Processing Record 16 of Set 16 | qena
# Processing Record 17 of Set 16 | shingu
# Processing Record 18 of Set 16 | shamary
# Processing Record 19 of Set 16 | ulaangom
# Processing Record 20 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 16 | belyy
# Processing Record 22 of Set 16 | tutoia
# Processing Record 23 of Set 16 | santa cruz
# Processing Record 24 of Set 16 | a
# City not found. Skipping...
# Processing Record 25 of Set 16 | segovia
# Processing Record 26 of Set 16 | lagoa
# Processing Record 27 of Set 16 | weiden
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
#Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     77.72        73          84
# 1        Barrow  71.2906 -156.7887    -25.60        68           1
# 2         Bluff -46.6000  168.3333     63.18        65         100
# 3      Hargeysa   9.5600   44.0650     58.80        95          72
# 4      Khatanga  71.9667  102.5000    -28.75        79           0
# 5    Vila Velha -20.3297  -40.2925     70.00        94          90
# 6  Puerto Ayora  -0.7393  -90.3518     77.00        96          93
# 7   Port Alfred -33.5906   26.8910     66.00        96          94
# 8     Busselton -33.6500  115.3333     64.00        99          86
# 9       Ushuaia -54.8000  -68.3000     55.40        71          20
#
#    Wind Speed Country Current Description
# 0       13.06      PF       broken clouds
# 1        9.22      US           clear sky
# 2        4.29      NZ       moderate rain
# 3       14.34      SO       broken clouds
# 4       11.07      RU           clear sky
# 5        8.70      BR       moderate rain
# 6        4.00      EC     overcast clouds
# 7        3.00      ZA     overcast clouds
# 8        1.99      AU     overcast clouds
# 9        8.05      AR          few clouds

# %%
#Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     77.72        73          84
# 1        Barrow      US  71.2906 -156.7887    -25.60        68           1
# 2         Bluff      NZ -46.6000  168.3333     63.18        65         100
# 3      Hargeysa      SO   9.5600   44.0650     58.80        95          72
# 4      Khatanga      RU  71.9667  102.5000    -28.75        79           0
# 5    Vila Velha      BR -20.3297  -40.2925     70.00        94          90
# 6  Puerto Ayora      EC  -0.7393  -90.3518     77.00        96          93
# 7   Port Alfred      ZA -33.5906   26.8910     66.00        96          94
# 8     Busselton      AU -33.6500  115.3333     64.00        99          86
# 9       Ushuaia      AR -54.8000  -68.3000     55.40        71          20
#
#    Wind Speed Current Description
# 0       13.06       broken clouds
# 1        9.22           clear sky
# 2        4.29       moderate rain
# 3       14.34       broken clouds
# 4       11.07           clear sky
# 5        8.70       moderate rain
# 6        4.00     overcast clouds
# 7        3.00     overcast clouds
# 8        1.99     overcast clouds
# 9        8.05          few clouds

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
